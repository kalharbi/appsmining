# %%
import pandas as pd
import numpy as np
import brewer2mpl
from IPython.display import HTML
# %matplotlib inline

# %%
def get_diff(dataframe, count_column_name, result_column_name):
    print('|==================================================================|')
    print('| The difference in ' + count_column_name + ' between multiple versions.|')
    print('|==================================================================|')
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    df_result = pd.DataFrame(columns=[first_index, 'number_of_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    for gp in dataframe.index.get_level_values(first_index).unique():
        tmp_df = dataframe.loc[gp, count_column_name]
        d = 0
        if len(tmp_df) == 1:
            d = 0
        else:
            for r in tmp_df:
                d = r - d
        df_result.ix[gp, result_column_name] = d
        df_result.ix[gp, 'number_of_versions'] = len(tmp_df)
    return df_result
    
def get_unique_diff(dataframe, count_column_name, result_column_name):
    print('|==================================================================|')
    print('| The difference in ' + count_column_name + ' between multiple versions.|')
    print('|==================================================================|')
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    df_result = pd.DataFrame(columns=[first_index, 'number_of_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    for gp in dataframe.index.get_level_values(first_index).unique():
        tmp_df = dataframe.loc[gp, count_column_name]
        d = 0
        if len(tmp_df) == 1:
            d = 0
        else:
            l = tmp_df.tolist()
            d =  l[-1] - l[0]
        df_result.ix[gp, result_column_name] = d
        df_result.ix[gp, 'number_of_versions'] = len(tmp_df)
    return df_result

# %%
def find_usage_in_any_release(dataframe, column_feature, show_no_matches=False):
    """Returns a dataframe that contains the package,number of packages, and first version number of the supported feature.
       Keyword arguments:
       dataframe -- the original dataframe indexed using a hierarchical indexing of package and version_code)
       column_feature -- the column name of a specific feature and must have boolean type values
       show_no_matches -- Include results even if the app does not support this feature.
       """
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    result_column_name = column_feature + '_first_supported_version'
    df_result = pd.DataFrame(columns=[first_index, 'available_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    # Get a list of unique packages
    packages = dataframe.index.get_level_values(first_index).unique()
    for package in packages:
        package_data_frame = dataframe.loc[package]
        # Get a list of supported versions for this package
        versions_list = package_data_frame[package_data_frame[column_feature]==True].index.tolist()
        # Exclude no matches
        if not versions_list and not show_no_matches:
            continue
        # Include no matches; use True or False
        found = False
        max_supported_version= np.NaN
        if versions_list:
            found = True
            max_supported_version = min(versions_list)
        # get the total number of available versions regardless of using this feature
        versions_count = len(package_data_frame.index)
        # only consider multiple versions
        if(versions_count == 1):
            continue
        # Add the most total versions and the most recent supported version to the result dataframe
        df_result.ix[package, 'available_versions'] = versions_count
        if show_no_matches:
            df_result.ix[package, 'support_this_feature'] = found
        df_result.ix[package, result_column_name] = max_supported_version
    return df_result

# %%
def find_usage_in_any_release_n(dataframe, column_feature, show_no_matches=False, opposite=False):
    """Returns a dataframe that contains the package,number of packages, and first version number of the supported feature.
       Keyword arguments:
       dataframe -- the original dataframe indexed using a hierarchical indexing of package and version_code)
       column_feature -- the column name of a specific feature and must have boolean type values
       show_no_matches -- Include results even if the app does not support this feature.
       """
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    result_column_name = column_feature + '_first_supported_version'
    df_result = pd.DataFrame(columns=[first_index, 'available_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    # Get a list of unique packages
    packages = dataframe.index.get_level_values(first_index).unique()
    for package in packages:
        package_data_frame = dataframe.loc[package]
        # Get a list of supported versions for this package
        versions_list = package_data_frame[package_data_frame[column_feature]>0].index.tolist()
        if opposite:
            versions_list = package_data_frame[package_data_frame[column_feature]==0].index.tolist()
        # Exclude no matches
        if not versions_list and not show_no_matches:
            continue
        # Include no matches; use True or False
        found = False
        max_supported_version= np.NaN
        if versions_list:
            found = True
            max_supported_version = min(versions_list)
        # get the total number of available versions regardless of using this feature
        versions_count = len(package_data_frame.index)
        # only consider multiple versions
        if(versions_count == 1):
            continue
        # Add the most total versions and the most recent supported version to the result dataframe
        df_result.ix[package, 'available_versions'] = versions_count
        if show_no_matches:
            df_result.ix[package, 'support_this_feature'] = found
        df_result.ix[package, result_column_name] = max_supported_version
    return df_result

# %%
# How many apps have still used this feature in the latest release.
def find_use_in_latest_release(dataframe, column_feature):
    """Returns a dataframe that contains the package,number of packages, and last version number of the supported feature.
       Keyword arguments:
       dataframe -- the original dataframe indexed using a hierarchical indexing of package and version_code)
       column_feature -- the column name of a specific feature and must have boolean type values
       """
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    result_column_name = column_feature + '_use_in_latest_version'
    df_result = pd.DataFrame(columns=[first_index, 'available_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    # Get a list of unique packages
    packages = dataframe.index.get_level_values(first_index).unique()
    for package in packages:
        package_data_frame = dataframe.loc[package]
        # Get a list of supported versions for this package
        supported_versions_list = package_data_frame[package_data_frame[column_feature]==True].index.tolist()
        unsupported_versions_list = package_data_frame[package_data_frame[column_feature]==False].index.tolist()
        # Exclude no matches
        if supported_versions_list is None or unsupported_versions_list is None:
            continue
        if len(supported_versions_list) == 0:
            continue
        # compare the two version lists
        try:
            max_supported_ver = max(supported_versions_list)
            max_unsupported_ver = max(unsupported_versions_list)
        except ValueError:
            pass
        # if the latest version still supports the feature and has no unsupported versions
        if(len(supported_versions_list) > 0 and len(unsupported_versions_list) == 0):
            max_supported_ver = max(supported_versions_list)
            max_unsupported_ver = -1000000
       
        # Include no matches; use True or False
        found = False
        # Return the first adopted version
        earlier_adopted_version= np.NaN
        if max_supported_ver > max_unsupported_ver:
            found = True
            earlier_adopted_version = max_supported_ver
        # get the total number of available versions regardless of adopting this feature
        versions_count = len(package_data_frame.index)
               # Do not compare single versions
        if versions_count == 1:
            continue
        # Add the total versions and the first supported version to the result dataframe
        df_result.ix[package, 'available_versions'] = versions_count
        df_result.ix[package, 'support_this_feature'] = found
        df_result.ix[package, result_column_name] = earlier_adopted_version
    return df_result

# %%
# How many apps have still used this feature in the latest release.
def find_use_in_latest_release_n(dataframe, column_feature, opposite=False):
    """Returns a dataframe that contains the package,number of packages, and last version number of the supported feature.
       Keyword arguments:
       dataframe -- the original dataframe indexed using a hierarchical indexing of package and version_code)
       column_feature -- the column name of a specific feature and must have boolean type values
       """
    # Get the first index name (package name)
    first_index = dataframe.index.names[0]
    result_column_name = column_feature + '_use_in_latest_version'
    df_result = pd.DataFrame(columns=[first_index, 'available_versions', result_column_name])
    df_result.set_index(first_index, inplace =True)
    # Get a list of unique packages
    packages = dataframe.index.get_level_values(first_index).unique()
    for package in packages:
        package_data_frame = dataframe.loc[package]
        # Get a list of supported versions for this package
        supported_versions_list = package_data_frame[package_data_frame[column_feature]>0].index.tolist()
        unsupported_versions_list = package_data_frame[package_data_frame[column_feature]==0].index.tolist()
        if opposite:
            supported_versions_list = package_data_frame[package_data_frame[column_feature]==0].index.tolist()
            unsupported_versions_list = package_data_frame[package_data_frame[column_feature]>0].index.tolist()
        # Exclude no matches
        if supported_versions_list is None or unsupported_versions_list is None:
            continue
        if len(supported_versions_list) == 0:
            continue
        # compare the two version lists
        try:
            max_supported_ver = max(supported_versions_list)
            max_unsupported_ver = max(unsupported_versions_list)
        except ValueError:
            pass
        # if the latest version still supports the feature and has no unsupported versions
        if(len(supported_versions_list) > 0 and len(unsupported_versions_list) == 0):
            max_supported_ver = max(supported_versions_list)
            max_unsupported_ver = -1000000
       
        # Include no matches; use True or False
        found = False
        # Return the first adopted version
        earlier_adopted_version= np.NaN
        if max_supported_ver > max_unsupported_ver:
            found = True
            earlier_adopted_version = max_supported_ver
        # get the total number of available versions regardless of adopting this feature
        versions_count = len(package_data_frame.index)
               # Do not compare single versions
        if versions_count == 1:
            continue
        # Add the total versions and the first supported version to the result dataframe
        df_result.ix[package, 'available_versions'] = versions_count
        df_result.ix[package, 'support_this_feature'] = found
        df_result.ix[package, result_column_name] = earlier_adopted_version
    return df_result

# %%
# Merge two dataframe with the most recent version
def merge_recent_apps_frame(dataframe_1, dataframe_details):
    # Get unique packages series
    df1 = dataframe_1
    df2 = dataframe_details
    df1= df1.reset_index()
    df2 = df2.reset_index()
    merged = pd.merge(df1,df2,on='package', suffixes=['_st','_nd'], how='inner')
    merged = merged.sort(['package','version_code'], ascending=True)
    merged = merged.drop_duplicates(subset='package', take_last=True)
    return merged

# %%
h = HTML('<h1>Apps Dataset Statistics</h1><hr/>'); h
# Out:
# <h1>Apps with Multiple Versions</h1><hr/>

# %%
df_apps = pd.read_csv('../results/chi-15/listing/top_free_apps_with_multiple_versions.csv')
df_apps.sort(columns=['package', 'version_code'], inplace=True)
df_apps.set_index(['package','version_code'], inplace=True)
df_apps.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Air.Lite, 1), (Air.Lite, 2), (Animaonline.FanFiction.Free, 67), (Animaonline.FanFiction.Free, 72), (AutomateIt.mainPackage, 79)]

# %%
print("Total of APK files with versions:" + str(len(df_apps)))
# Out:
# Total of APK files with versions:56349

# %%
# Number of unique package names
packages = df_apps.index.get_level_values(df_apps.index.names[0]).unique()
print("Total of number of unique apps: ", len(packages))
# Out:
# Total of number of unique apps:  24436

# %%
# Get the number of versions per app
first_index = df_apps.index.names[0]
df_summary = pd.DataFrame(columns=[first_index, 'number_of_versions'])
df_summary.set_index(first_index, inplace =True)
for gp in df_apps.index.get_level_values(first_index).unique():
    tmp_df = df_apps.loc[gp]
    df_summary.ix[gp, 'number_of_versions'] = len(tmp_df)
print ('min  | ' + str(df_summary.number_of_versions.min()))
print ('max  |' + str(df_summary.number_of_versions.max()))
print ('mean | ' + str(df_summary.number_of_versions.mean()))
print ('std  |' + str(df_summary.number_of_versions.std()))
df_summary.head()
# Out:
# min  | 2
# max  |17
# mean | 2.305982975937142
# std  |0.753388506292
#                             number_of_versions
# package
# Air.Lite                                     2
# Animaonline.FanFiction.Free                  2
# AutomateIt.mainPackage                       2
# B4A.Agroid_software                          3
# B4A.BigFivePersonalityTest                   2

# %%
t = df_summary.groupby(['number_of_versions']).size()
print(t)
#colorbrewer2 Dark2 qualitative color table
dark2_colors = brewer2mpl.get_map('Dark2', 'Qualitative', 7).mpl_colors
plt.subplot(aspect=True)
plt.pie(t, labels=t.index.values, colors = dark2_colors[0:5], autopct='%i%%')
plt.legend()
plt.title("Number of multiple releases in our dataset")
savefig('/Users/khalid/git/appsmining/results/chi-15/images/figures/data-distribution.png', dpi=100, format='png')
# Out:
# number_of_versions
# 2                     19566
# 3                      3279
# 4                       985
# 5                       360
# 6                       154
# 7                        50
# 8                        24
# 9                        14
# 10                        2
# 11                        1
# 17                        1
# dtype: int64

# %%
t.to_csv('/Users/Khalid/Desktop/charts/versions_count.csv')

# %%
df_details = pd.read_csv('/Users/Khalid/git/appsmining/results/chi-15/listing/additional_info.csv')
df_details.sort(columns=['package','version_code'], inplace=True)
df_details.set_index(['package','version_code'], inplace=True)
df_details.head()
# Out:
#                                          version_name  \
# package                     version_code
# Air.Lite                    1                     1.0
#                             2                     1.1
# Animaonline.FanFiction.Free 67                  4.0.6
#                             72                  4.2.3
# AutomateIt.mainPackage      79                 3.0.79
#
#                                                                    title  \
# package                     version_code
# Air.Lite                    1               Air Lite Psychrometric Calcs
#                             2                           Air Control Lite
# Animaonline.FanFiction.Free 67                         FanFiction Reader
#                             72                         FanFiction Reader
# AutomateIt.mainPackage      79            AutomateIt-Automate Your Droid
#
#                                                    category    rating  \
# package                     version_code
# Air.Lite                    1                  Productivity  4.578432
#                             2                  Productivity  4.200000
# Animaonline.FanFiction.Free 67            Books & Reference  4.439602
#                             72            Books & Reference  4.435376
# AutomateIt.mainPackage      79                 Productivity  4.294265
#
#                                           download date_published  \
# package                     version_code
# Air.Lite                    1                50000     2011-05-21
#                             2                50000     2014-06-17
# Animaonline.FanFiction.Free 67              100000     2013-12-07
#                             72              100000     2013-12-11
# AutomateIt.mainPackage      79              100000     2013-11-20
#
#                                                                 developer  \
# package                     version_code
# Air.Lite                    1             Cold Means Mobile Software, LLC
#                             2                                 Four Pixels
# Animaonline.FanFiction.Free 67                                   JMT Apps
#                             72                                   JMT Apps
# AutomateIt.mainPackage      79                            SmarterApps Ltd
#
#                                           total_permissions  \
# package                     version_code
# Air.Lite                    1                             2
#                             2                             2
# Animaonline.FanFiction.Free 67                            8
#                             72                            9
# AutomateIt.mainPackage      79                           36
#
#                                                                                 permissions
# package                     version_code
# Air.Lite                    1             android.permission.INTERNET,android.permission...
#                             2             android.permission.INTERNET,android.permission...
# Animaonline.FanFiction.Free 67            android.permission.ACCESS_NETWORK_STATE,androi...
#                             72            android.permission.ACCESS_NETWORK_STATE,androi...
# AutomateIt.mainPackage      79            android.permission.DISABLE_KEYGUARD,android.pe...

# %%
h = HTML("<h2>Apps by download count</h2>"); h
# Out:
# <h2>Apps by download count</h2>

# %%
df_details[df_details.download == 1]
# Out:
#                                                                   version_name  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001             2.0.1
# air.com.clarinio.ShuffleVegetables.A8                2000000             2.0.0
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                     1.0
# com.Beer_Run                                         97                    1.0
# com.Tobit.android.Slitte6376406122                   2722                2.722
#                                                      2739                2.739
# com.Tobit.android.Slitte6414103674                   2737                2.737
#                                                      2739                2.739
# com.Tobit.android.Slitte6429412370                   2722                2.722
#                                                      2739                2.739
# com.Tobit.android.Slitte6438218649                   2739                2.739
#                                                      2747                2.747
# com.andromo.dev137436.app223888                      1                     1.0
# com.appexpress.alwaysbestcareseniorservices          39                  2.0.2
# com.appexpress.centurychimneysweep                   39                  2.0.2
# com.appexpress.nicholsdrygoods                       44                  2.0.5
# com.appexpress.normangaragedoorinc                   39                  2.0.2
#                                                      43                  2.0.5
# com.appexpress.troopindustrial                       39                  2.0.2
# com.appserpro.europeunique                           2                     2.0
# com.attorneyconnect_llc.attorney_david_l_rubin       103                 1.0.3
#                                                      104                 1.0.4
# com.attorneyconnect_llc.attorney_geoffrey_german     101                 1.0.1
# com.attorneyconnect_llc.attorney_michael_franklin    101                 1.0.1
#                                                      102                 1.0.2
# com.capitalideations.chapter_ten_page_one_af         2                     2.0
# com.cardwise.xpenditureC                             1                     1.0
# com.cga.flexeqassignment                             1                     1.0
# com.clarga.chris                                     1                   1.1.1
# com.clockworks.kdb_art                               3                     1.1
# com.crowdcompass.appoIAqOJ5wSl                       117                   1.7
#                                                      1118                 1.18
# com.evansimpson.olindining                           1                     0.8
# com.ggp.theclub.firstcolonymall                      41                  3.0.2
# com.howtobuildselfconfidence.increaseconfidencelevel 1                     1.0
# com.lbc.mylegacy                                     1                     NaN
# com.pshetye.typeanything                             1                     1.0
# com.reverbnation.artistapp.i764919                   1160                1.1.6
# com.revolutionfm.streamingmedia                      4                   1.0.0
#                                                      5                   1.0.0
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                    1.01
# com.ssssoft.cashregisterdemo                         1                     1.0
# com.vandsolutions.fuelspend                          1                     1.0
# com.ylamaki.lunchwheel                               1                   1.0.0
# eight.app.studio.sweetToothDay                       101                 1.0.1
# es.eduxdream.adult                                   1                     1.0
# fr.rainbowstar.mume                                  1                     1.0
# it.sesinet.museiumbri                                1                       1
# me.doubledutch.coldchaingdpglobalforum               26                3.7.2.2
# nl.mediamatic.ikpollmobile.ahm08                     105                 1.0.5
# pt.worldit.contentscanner                            4                     1.3
# ru.kvitalyv.r.schumannromance                        4                     4.0
# yluo.android.appointmentcare                         1                     1.0
#
#                                                                                             title  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001       Puzzle - Fruits and Vegetables
# air.com.clarinio.ShuffleVegetables.A8                2000000       Shuffle: Fruits and Vegetables
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                        Sexual Assault Talk
# com.Beer_Run                                         97                              Mahjong Pair
# com.Tobit.android.Slitte6376406122                   2722             Tourist-Information Colditz
#                                                      2739             Tourist-Information Colditz
# com.Tobit.android.Slitte6414103674                   2737                     Field Electronic Ug
#                                                      2739                     Field Electronic Ug
# com.Tobit.android.Slitte6429412370                   2722                           Nervous Nerds
#                                                      2739                           Nervous Nerds
# com.Tobit.android.Slitte6438218649                   2739                 Singer & Leibfried GmbH
#                                                      2747                 Singer & Leibfried GmbH
# com.andromo.dev137436.app223888                      1             Presidents Inaugural Addresses
# com.appexpress.alwaysbestcareseniorservices          39            Always Best Care Senior Servic
# com.appexpress.centurychimneysweep                   39                     Century Chimney Sweep
# com.appexpress.nicholsdrygoods                       44                         Nichols Dry Goods
# com.appexpress.normangaragedoorinc                   39                   Norman Garage Door Inc.
#                                                      43                   Norman Garage Door Inc.
# com.appexpress.troopindustrial                       39                          Troop Industrial
# com.appserpro.europeunique                           2                              Europe Unique
# com.attorneyconnect_llc.attorney_david_l_rubin       103                  Attorney David L. Rubin
#                                                      104                  Attorney David L. Rubin
# com.attorneyconnect_llc.attorney_geoffrey_german     101                 Attorney Geoffrey German
# com.attorneyconnect_llc.attorney_michael_franklin    101                Attorney Michael Franklin
#                                                      102                Attorney Michael Franklin
# com.capitalideations.chapter_ten_page_one_af         2                    Chapter Ten Page One AF
# com.cardwise.xpenditureC                             1              PCS XPNS (CREACARD Corporate)
# com.cga.flexeqassignment                             1                  Flex Equipment Assignment
# com.clarga.chris                                     1                   Kunyu-Kunyu -Omotenashi-
# com.clockworks.kdb_art                               3              Korean Traditional Craft Fair
# com.crowdcompass.appoIAqOJ5wSl                       117           PCMA - Northern California App
#                                                      1118          PCMA - Northern California App
# com.evansimpson.olindining                           1                                Olin Dining
# com.ggp.theclub.firstcolonymall                      41                         First Colony Mall
# com.howtobuildselfconfidence.increaseconfidencelevel 1                      Build Self Confidence
# com.lbc.mylegacy                                     1                                  My Legacy
# com.pshetye.typeanything                             1                              Type Anything
# com.reverbnation.artistapp.i764919                   1160                       Howard Lips Music
# com.revolutionfm.streamingmedia                      4                              Revolution FM
#                                                      5                              Revolution FM
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                       Salt River Golf Club
# com.ssssoft.cashregisterdemo                         1                        POS - Cash Register
# com.vandsolutions.fuelspend                          1                                 Fuel Spend
# com.ylamaki.lunchwheel                               1                                Lunch Wheel
# eight.app.studio.sweetToothDay                       101                          Sweet Tooth Day
# es.eduxdream.adult                                   1                                  Legal Age
# fr.rainbowstar.mume                                  1                MUME, Exile Memorial Museum
# it.sesinet.museiumbri                                1               Umbria Museums and Monuments
# me.doubledutch.coldchaingdpglobalforum               26               Cold Chain GDP Global Forum
# nl.mediamatic.ikpollmobile.ahm08                     105                  IkPoll Amsterdam Museum
# pt.worldit.contentscanner                            4                            Content Scanner
# ru.kvitalyv.r.schumannromance                        4                        Schumann R. Romance
# yluo.android.appointmentcare                         1              Automatic Appointment Manager
#
#                                                                             category  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001          Brain & Puzzle
# air.com.clarinio.ShuffleVegetables.A8                2000000          Brain & Puzzle
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                 Communication
# com.Beer_Run                                         97                Entertainment
# com.Tobit.android.Slitte6376406122                   2722             Travel & Local
#                                                      2739             Travel & Local
# com.Tobit.android.Slitte6414103674                   2737                   Business
#                                                      2739                   Business
# com.Tobit.android.Slitte6429412370                   2722                  Lifestyle
#                                                      2739                  Lifestyle
# com.Tobit.android.Slitte6438218649                   2739             Travel & Local
#                                                      2747             Travel & Local
# com.andromo.dev137436.app223888                      1             Books & Reference
# com.appexpress.alwaysbestcareseniorservices          39                     Business
# com.appexpress.centurychimneysweep                   39                     Business
# com.appexpress.nicholsdrygoods                       44                     Business
# com.appexpress.normangaragedoorinc                   39                     Business
#                                                      43                     Business
# com.appexpress.troopindustrial                       39                     Business
# com.appserpro.europeunique                           2                     Lifestyle
# com.attorneyconnect_llc.attorney_david_l_rubin       103                    Business
#                                                      104                    Business
# com.attorneyconnect_llc.attorney_geoffrey_german     101                    Business
# com.attorneyconnect_llc.attorney_michael_franklin    101                    Business
#                                                      102                    Business
# com.capitalideations.chapter_ten_page_one_af         2                Brain & Puzzle
# com.cardwise.xpenditureC                             1                       Finance
# com.cga.flexeqassignment                             1                      Business
# com.clarga.chris                                     1                        Casual
# com.clockworks.kdb_art                               3             Books & Reference
# com.crowdcompass.appoIAqOJ5wSl                       117                    Business
#                                                      1118                   Business
# com.evansimpson.olindining                           1             Books & Reference
# com.ggp.theclub.firstcolonymall                      41                    Lifestyle
# com.howtobuildselfconfidence.increaseconfidencelevel 1                        Social
# com.lbc.mylegacy                                     1                     Lifestyle
# com.pshetye.typeanything                             1                  Productivity
# com.reverbnation.artistapp.i764919                   1160              Music & Audio
# com.revolutionfm.streamingmedia                      4                 Entertainment
#                                                      5                 Entertainment
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                Travel & Local
# com.ssssoft.cashregisterdemo                         1                      Business
# com.vandsolutions.fuelspend                          1                  Productivity
# com.ylamaki.lunchwheel                               1                Travel & Local
# eight.app.studio.sweetToothDay                       101             Arcade & Action
# es.eduxdream.adult                                   1                         Tools
# fr.rainbowstar.mume                                  1                     Education
# it.sesinet.museiumbri                                1                     Education
# me.doubledutch.coldchaingdpglobalforum               26                       Social
# nl.mediamatic.ikpollmobile.ahm08                     105                       Tools
# pt.worldit.contentscanner                            4                      Business
# ru.kvitalyv.r.schumannromance                        4             Books & Reference
# yluo.android.appointmentcare                         1                      Business
#
#                                                                    rating  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001          3.4
# air.com.clarinio.ShuffleVegetables.A8                2000000          5.0
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                0.0
# com.Beer_Run                                         97               5.0
# com.Tobit.android.Slitte6376406122                   2722             5.0
#                                                      2739             5.0
# com.Tobit.android.Slitte6414103674                   2737             5.0
#                                                      2739             5.0
# com.Tobit.android.Slitte6429412370                   2722             0.0
#                                                      2739             0.0
# com.Tobit.android.Slitte6438218649                   2739             0.0
#                                                      2747             0.0
# com.andromo.dev137436.app223888                      1                0.0
# com.appexpress.alwaysbestcareseniorservices          39               0.0
# com.appexpress.centurychimneysweep                   39               0.0
# com.appexpress.nicholsdrygoods                       44               0.0
# com.appexpress.normangaragedoorinc                   39               0.0
#                                                      43               0.0
# com.appexpress.troopindustrial                       39               0.0
# com.appserpro.europeunique                           2                0.0
# com.attorneyconnect_llc.attorney_david_l_rubin       103              0.0
#                                                      104              0.0
# com.attorneyconnect_llc.attorney_geoffrey_german     101              0.0
# com.attorneyconnect_llc.attorney_michael_franklin    101              0.0
#                                                      102              0.0
# com.capitalideations.chapter_ten_page_one_af         2                0.0
# com.cardwise.xpenditureC                             1                0.0
# com.cga.flexeqassignment                             1                5.0
# com.clarga.chris                                     1                0.0
# com.clockworks.kdb_art                               3                0.0
# com.crowdcompass.appoIAqOJ5wSl                       117              0.0
#                                                      1118             0.0
# com.evansimpson.olindining                           1                0.0
# com.ggp.theclub.firstcolonymall                      41               0.0
# com.howtobuildselfconfidence.increaseconfidencelevel 1                0.0
# com.lbc.mylegacy                                     1                0.0
# com.pshetye.typeanything                             1                5.0
# com.reverbnation.artistapp.i764919                   1160             5.0
# com.revolutionfm.streamingmedia                      4                0.0
#                                                      5                5.0
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                0.0
# com.ssssoft.cashregisterdemo                         1                5.0
# com.vandsolutions.fuelspend                          1                5.0
# com.ylamaki.lunchwheel                               1                0.0
# eight.app.studio.sweetToothDay                       101              5.0
# es.eduxdream.adult                                   1                5.0
# fr.rainbowstar.mume                                  1                0.0
# it.sesinet.museiumbri                                1                0.0
# me.doubledutch.coldchaingdpglobalforum               26               0.0
# nl.mediamatic.ikpollmobile.ahm08                     105              0.0
# pt.worldit.contentscanner                            4                0.0
# ru.kvitalyv.r.schumannromance                        4                0.0
# yluo.android.appointmentcare                         1                0.0
#
#                                                                    download  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001              1
# air.com.clarinio.ShuffleVegetables.A8                2000000              1
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                    1
# com.Beer_Run                                         97                   1
# com.Tobit.android.Slitte6376406122                   2722                 1
#                                                      2739                 1
# com.Tobit.android.Slitte6414103674                   2737                 1
#                                                      2739                 1
# com.Tobit.android.Slitte6429412370                   2722                 1
#                                                      2739                 1
# com.Tobit.android.Slitte6438218649                   2739                 1
#                                                      2747                 1
# com.andromo.dev137436.app223888                      1                    1
# com.appexpress.alwaysbestcareseniorservices          39                   1
# com.appexpress.centurychimneysweep                   39                   1
# com.appexpress.nicholsdrygoods                       44                   1
# com.appexpress.normangaragedoorinc                   39                   1
#                                                      43                   1
# com.appexpress.troopindustrial                       39                   1
# com.appserpro.europeunique                           2                    1
# com.attorneyconnect_llc.attorney_david_l_rubin       103                  1
#                                                      104                  1
# com.attorneyconnect_llc.attorney_geoffrey_german     101                  1
# com.attorneyconnect_llc.attorney_michael_franklin    101                  1
#                                                      102                  1
# com.capitalideations.chapter_ten_page_one_af         2                    1
# com.cardwise.xpenditureC                             1                    1
# com.cga.flexeqassignment                             1                    1
# com.clarga.chris                                     1                    1
# com.clockworks.kdb_art                               3                    1
# com.crowdcompass.appoIAqOJ5wSl                       117                  1
#                                                      1118                 1
# com.evansimpson.olindining                           1                    1
# com.ggp.theclub.firstcolonymall                      41                   1
# com.howtobuildselfconfidence.increaseconfidencelevel 1                    1
# com.lbc.mylegacy                                     1                    1
# com.pshetye.typeanything                             1                    1
# com.reverbnation.artistapp.i764919                   1160                 1
# com.revolutionfm.streamingmedia                      4                    1
#                                                      5                    1
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                    1
# com.ssssoft.cashregisterdemo                         1                    1
# com.vandsolutions.fuelspend                          1                    1
# com.ylamaki.lunchwheel                               1                    1
# eight.app.studio.sweetToothDay                       101                  1
# es.eduxdream.adult                                   1                    1
# fr.rainbowstar.mume                                  1                    1
# it.sesinet.museiumbri                                1                    1
# me.doubledutch.coldchaingdpglobalforum               26                   1
# nl.mediamatic.ikpollmobile.ahm08                     105                  1
# pt.worldit.contentscanner                            4                    1
# ru.kvitalyv.r.schumannromance                        4                    1
# yluo.android.appointmentcare                         1                    1
#
#                                                                   date_published  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001          2014-01-01
# air.com.clarinio.ShuffleVegetables.A8                2000000          2014-01-01
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                2014-01-09
# com.Beer_Run                                         97               2013-12-14
# com.Tobit.android.Slitte6376406122                   2722             2013-12-14
#                                                      2739             2014-01-11
# com.Tobit.android.Slitte6414103674                   2737             2014-01-09
#                                                      2739             2014-01-11
# com.Tobit.android.Slitte6429412370                   2722             2013-12-14
#                                                      2739             2014-01-11
# com.Tobit.android.Slitte6438218649                   2739             2014-01-12
#                                                      2747             2014-01-18
# com.andromo.dev137436.app223888                      1                2013-07-04
# com.appexpress.alwaysbestcareseniorservices          39               2013-08-05
# com.appexpress.centurychimneysweep                   39               2013-08-02
# com.appexpress.nicholsdrygoods                       44               2013-10-30
# com.appexpress.normangaragedoorinc                   39               2013-08-04
#                                                      43               2013-10-08
# com.appexpress.troopindustrial                       39               2013-08-01
# com.appserpro.europeunique                           2                2013-11-22
# com.attorneyconnect_llc.attorney_david_l_rubin       103              2013-09-03
#                                                      104              2013-11-07
# com.attorneyconnect_llc.attorney_geoffrey_german     101              2013-11-08
# com.attorneyconnect_llc.attorney_michael_franklin    101              2013-09-03
#                                                      102              2013-11-08
# com.capitalideations.chapter_ten_page_one_af         2                2013-11-25
# com.cardwise.xpenditureC                             1                2013-11-29
# com.cga.flexeqassignment                             1                2013-12-20
# com.clarga.chris                                     1                2013-12-10
# com.clockworks.kdb_art                               3                2013-08-26
# com.crowdcompass.appoIAqOJ5wSl                       117              2013-11-26
#                                                      1118             2014-05-30
# com.evansimpson.olindining                           1                2013-12-12
# com.ggp.theclub.firstcolonymall                      41               2014-01-16
# com.howtobuildselfconfidence.increaseconfidencelevel 1                2013-11-25
# com.lbc.mylegacy                                     1                2014-01-13
# com.pshetye.typeanything                             1                2014-01-09
# com.reverbnation.artistapp.i764919                   1160             2012-11-16
# com.revolutionfm.streamingmedia                      4                2013-12-26
#                                                      5                2014-02-09
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                2012-04-06
# com.ssssoft.cashregisterdemo                         1                2014-01-22
# com.vandsolutions.fuelspend                          1                2013-08-10
# com.ylamaki.lunchwheel                               1                2013-12-09
# eight.app.studio.sweetToothDay                       101              2014-01-29
# es.eduxdream.adult                                   1                2013-07-31
# fr.rainbowstar.mume                                  1                2013-12-03
# it.sesinet.museiumbri                                1                2013-12-11
# me.doubledutch.coldchaingdpglobalforum               26               2013-09-02
# nl.mediamatic.ikpollmobile.ahm08                     105              2013-04-17
# pt.worldit.contentscanner                            4                2013-12-24
# ru.kvitalyv.r.schumannromance                        4                2014-04-30
# yluo.android.appointmentcare                         1                2014-01-04
#
#                                                                                                 developer  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001                                     Clarinio
# air.com.clarinio.ShuffleVegetables.A8                2000000                                     Clarinio
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                                    houstonhilton74
# com.Beer_Run                                         97                                       Apps Gempro
# com.Tobit.android.Slitte6376406122                   2722                             Tobit.Software GER8
#                                                      2739                             Tobit.Software GER8
# com.Tobit.android.Slitte6414103674                   2737                            Tobit.Software GER19
#                                                      2739                            Tobit.Software GER19
# com.Tobit.android.Slitte6429412370                   2722                             Tobit.Software GER2
#                                                      2739                             Tobit.Software GER2
# com.Tobit.android.Slitte6438218649                   2739                             Tobit.Software GER3
#                                                      2747                             Tobit.Software GER3
# com.andromo.dev137436.app223888                      1                                            AMSApps
# com.appexpress.alwaysbestcareseniorservices          39                  Always Best Care Senior Services
# com.appexpress.centurychimneysweep                   39                                       CenturyChim
# com.appexpress.nicholsdrygoods                       44                                 Nichols Dry Goods
# com.appexpress.normangaragedoorinc                   39                            Norman Garage Door INC
#                                                      43                            Norman Garage Door INC
# com.appexpress.troopindustrial                       39                                  Troop Industrial
# com.appserpro.europeunique                           2             AXSERPRO MARKETING CONSULTANCY PTE LTD
# com.attorneyconnect_llc.attorney_david_l_rubin       103                              AttorneyConnect LLC
#                                                      104                              AttorneyConnect LLC
# com.attorneyconnect_llc.attorney_geoffrey_german     101                              AttorneyConnect LLC
# com.attorneyconnect_llc.attorney_michael_franklin    101                              AttorneyConnect LLC
#                                                      102                              AttorneyConnect LLC
# com.capitalideations.chapter_ten_page_one_af         2                              Capital Ideations LLC
# com.cardwise.xpenditureC                             1                                           Cardwise
# com.cga.flexeqassignment                             1                                   CGA Software Ltd
# com.clarga.chris                                     1                                       ã¯ã©ãã¼
# com.clockworks.kdb_art                               3                                     KDB Foundation
# com.crowdcompass.appoIAqOJ5wSl                       117                                 CrowdCompass Inc
#                                                      1118                                CrowdCompass Inc
# com.evansimpson.olindining                           1                                           OlinApps
# com.ggp.theclub.firstcolonymall                      41                                              GGMI
# com.howtobuildselfconfidence.increaseconfidencelevel 1                                     downtodownload
# com.lbc.mylegacy                                     1                           Legacy Business Cultures
# com.pshetye.typeanything                             1                                  Prathamesh Shetye
# com.reverbnation.artistapp.i764919                   1160                        ReverbNation Artists (4)
# com.revolutionfm.streamingmedia                      4                             W.E.B. Enterprises Ltd
#                                                      5                             W.E.B. Enterprises Ltd
# com.softpower.android.webviewapp.SaltRiverGolfClub   1              Golf Channel Solutions - Website Team
# com.ssssoft.cashregisterdemo                         1                                        Vijay Yande
# com.vandsolutions.fuelspend                          1                                      vanDSolutions
# com.ylamaki.lunchwheel                               1                                            Ylamaki
# eight.app.studio.sweetToothDay                       101                                       8AppStudio
# es.eduxdream.adult                                   1                                          eduxdream
# fr.rainbowstar.mume                                  1                  RainbowStar Software Thibaut EIRL
# it.sesinet.museiumbri                                1                                          Liquidapp
# me.doubledutch.coldchaingdpglobalforum               26                                       DoubleDutch
# nl.mediamatic.ikpollmobile.ahm08                     105                                   Mediamatic Lab
# pt.worldit.contentscanner                            4                                            WorldIT
# ru.kvitalyv.r.schumannromance                        4                                          KVitaliyV
# yluo.android.appointmentcare                         1                     Appointment.Care2014@gmail.com
#
#                                                                    total_permissions  \
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001                       7
# air.com.clarinio.ShuffleVegetables.A8                2000000                       7
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1                             3
# com.Beer_Run                                         97                           17
# com.Tobit.android.Slitte6376406122                   2722                          8
#                                                      2739                          8
# com.Tobit.android.Slitte6414103674                   2737                          8
#                                                      2739                          8
# com.Tobit.android.Slitte6429412370                   2722                          8
#                                                      2739                          8
# com.Tobit.android.Slitte6438218649                   2739                          8
#                                                      2747                          8
# com.andromo.dev137436.app223888                      1                             4
# com.appexpress.alwaysbestcareseniorservices          39                           17
# com.appexpress.centurychimneysweep                   39                           17
# com.appexpress.nicholsdrygoods                       44                           17
# com.appexpress.normangaragedoorinc                   39                           17
#                                                      43                           17
# com.appexpress.troopindustrial                       39                           17
# com.appserpro.europeunique                           2                             2
# com.attorneyconnect_llc.attorney_david_l_rubin       103                          18
#                                                      104                          18
# com.attorneyconnect_llc.attorney_geoffrey_german     101                          18
# com.attorneyconnect_llc.attorney_michael_franklin    101                          18
#                                                      102                          18
# com.capitalideations.chapter_ten_page_one_af         2                             2
# com.cardwise.xpenditureC                             1                             4
# com.cga.flexeqassignment                             1                             4
# com.clarga.chris                                     1                             2
# com.clockworks.kdb_art                               3                             4
# com.crowdcompass.appoIAqOJ5wSl                       117                          13
#                                                      1118                         13
# com.evansimpson.olindining                           1                             1
# com.ggp.theclub.firstcolonymall                      41                           13
# com.howtobuildselfconfidence.increaseconfidencelevel 1                            10
# com.lbc.mylegacy                                     1                             8
# com.pshetye.typeanything                             1                             0
# com.reverbnation.artistapp.i764919                   1160                         10
# com.revolutionfm.streamingmedia                      4                             2
#                                                      5                             3
# com.softpower.android.webviewapp.SaltRiverGolfClub   1                             4
# com.ssssoft.cashregisterdemo                         1                             3
# com.vandsolutions.fuelspend                          1                             0
# com.ylamaki.lunchwheel                               1                             4
# eight.app.studio.sweetToothDay                       101                           7
# es.eduxdream.adult                                   1                             8
# fr.rainbowstar.mume                                  1                             2
# it.sesinet.museiumbri                                1                             8
# me.doubledutch.coldchaingdpglobalforum               26                           14
# nl.mediamatic.ikpollmobile.ahm08                     105                           5
# pt.worldit.contentscanner                            4                            10
# ru.kvitalyv.r.schumannromance                        4                             3
# yluo.android.appointmentcare                         1                             5
#
#                                                                                                          permissions
# package                                              version_code
# air.com.clarinio.PuzzleVegetables.A3                 2000001       android.permission.INTERNET,android.permission...
# air.com.clarinio.ShuffleVegetables.A8                2000000       android.permission.INTERNET,android.permission...
# appinventor.ai_houstonhilton74.Sexual_Assault_Talk   1             android.permission.INTERNET,android.permission...
# com.Beer_Run                                         97            android.permission.INTERNET,android.permission...
# com.Tobit.android.Slitte6376406122                   2722          android.permission.INTERNET,android.permission...
#                                                      2739          android.permission.INTERNET,android.permission...
# com.Tobit.android.Slitte6414103674                   2737          android.permission.INTERNET,android.permission...
#                                                      2739          android.permission.INTERNET,android.permission...
# com.Tobit.android.Slitte6429412370                   2722          android.permission.INTERNET,android.permission...
#                                                      2739          android.permission.INTERNET,android.permission...
# com.Tobit.android.Slitte6438218649                   2739          android.permission.INTERNET,android.permission...
#                                                      2747          android.permission.INTERNET,android.permission...
# com.andromo.dev137436.app223888                      1             android.permission.INTERNET,android.permission...
# com.appexpress.alwaysbestcareseniorservices          39            android.permission.CALL_PHONE,android.permissi...
# com.appexpress.centurychimneysweep                   39            android.permission.CALL_PHONE,android.permissi...
# com.appexpress.nicholsdrygoods                       44            android.permission.CALL_PHONE,android.permissi...
# com.appexpress.normangaragedoorinc                   39            android.permission.CALL_PHONE,android.permissi...
#                                                      43            android.permission.CALL_PHONE,android.permissi...
# com.appexpress.troopindustrial                       39            android.permission.CALL_PHONE,android.permissi...
# com.appserpro.europeunique                           2             android.permission.INTERNET,android.permission...
# com.attorneyconnect_llc.attorney_david_l_rubin       103           android.permission.INTERNET,android.permission...
#                                                      104           android.permission.INTERNET,android.permission...
# com.attorneyconnect_llc.attorney_geoffrey_german     101           android.permission.INTERNET,android.permission...
# com.attorneyconnect_llc.attorney_michael_franklin    101           android.permission.INTERNET,android.permission...
#                                                      102           android.permission.INTERNET,android.permission...
# com.capitalideations.chapter_ten_page_one_af         2             android.permission.INTERNET,android.permission...
# com.cardwise.xpenditureC                             1             android.permission.INTERNET,android.permission...
# com.cga.flexeqassignment                             1             android.permission.INTERNET,android.permission...
# com.clarga.chris                                     1             android.permission.INTERNET,android.permission...
# com.clockworks.kdb_art                               3             android.permission.INTERNET,android.permission...
# com.crowdcompass.appoIAqOJ5wSl                       117           android.permission.INTERNET,android.permission...
#                                                      1118          android.permission.INTERNET,android.permission...
# com.evansimpson.olindining                           1                                   android.permission.INTERNET
# com.ggp.theclub.firstcolonymall                      41            android.permission.INTERNET,android.permission...
# com.howtobuildselfconfidence.increaseconfidencelevel 1             android.permission.INTERNET,android.permission...
# com.lbc.mylegacy                                     1             android.permission.INTERNET,android.permission...
# com.pshetye.typeanything                             1                                                           NaN
# com.reverbnation.artistapp.i764919                   1160          android.permission.INTERNET,android.permission...
# com.revolutionfm.streamingmedia                      4             android.permission.ACCESS_NETWORK_STATE,androi...
#                                                      5             android.permission.ACCESS_NETWORK_STATE,androi...
# com.softpower.android.webviewapp.SaltRiverGolfClub   1             android.permission.INTERNET,android.permission...
# com.ssssoft.cashregisterdemo                         1             android.permission.WRITE_SETTINGS,android.perm...
# com.vandsolutions.fuelspend                          1                                                           NaN
# com.ylamaki.lunchwheel                               1             android.permission.INTERNET,android.permission...
# eight.app.studio.sweetToothDay                       101           android.permission.INTERNET,android.permission...
# es.eduxdream.adult                                   1             android.permission.INTERNET,android.permission...
# fr.rainbowstar.mume                                  1             android.permission.INTERNET,android.permission...
# it.sesinet.museiumbri                                1             android.permission.WAKE_LOCK,android.permissio...
# me.doubledutch.coldchaingdpglobalforum               26            android.permission.INTERNET,android.permission...
# nl.mediamatic.ikpollmobile.ahm08                     105           android.permission.INTERNET,android.permission...
# pt.worldit.contentscanner                            4             android.permission.CAMERA,android.permission.W...
# ru.kvitalyv.r.schumannromance                        4             android.permission.INTERNET,android.permission...
# yluo.android.appointmentcare                         1             android.permission.RECEIVE_SMS,android.permiss...

# %%
# Count how many apps by download count
all_downs = df_details['download'].reset_index(drop=True)
table_frame = pd.DataFrame(0, index = np.arange(len(all_downs)), columns = all_downs.unique())
count = 0
for download in all_downs:
    table_frame.ix[count, download] = 1
    count += 1
#table_frame.head()

# %%
table_frame.sum().to_csv('/Users/Khalid/Dropbox/Public/charts/apps_by_download_2.csv')

# %%
table_frame.sum().plot(kind='barh', figsize=(30, 20),  color=['r','g','c', 'm','y','k', '#00F5B8', '#B88A00'])
ylabel('Downloads')
xlabel('Number of apps')
savefig('/Users/khalid/git/appsmining/results/chi-15/images/figures/apps_by_download.png', dpi=100, format='png')

# %%
h = HTML("<h1>Horizontal Paging</h1>"); h
# Out:
# <h1>Horizontal Paging</h1>

# %%
df_h_paging = pd.read_csv('/Users/khalid/git/appsmining/results/chi-15/ui/android.support.v4.view.ViewPager.csv')
df_h_paging.set_index(['package','version_code'], inplace=True)
df_h_paging.head()
# Out:
#                                                        use_android.support.v4.view.ViewPager_elements  \
# package                                   version_code
# com.monotype.android.font.fonts4fun.metal 15                                                    False
# com.airkast.WKJSFM                        36                                                    False
# com.ibsys.app.pns_jax                     855                                                    True
# com.knu.ibuttons                          12                                                    False
# com.icaw.guessthecar                      15                                                    False
#
#                                                         count  \
# package                                   version_code
# com.monotype.android.font.fonts4fun.metal 15                0
# com.airkast.WKJSFM                        36                0
# com.ibsys.app.pns_jax                     855               5
# com.knu.ibuttons                          12                0
# com.icaw.guessthecar                      15                0
#
#                                                                                                     files
# package                                   version_code
# com.monotype.android.font.fonts4fun.metal 15                                                          NaN
# com.airkast.WKJSFM                        36                                                          NaN
# com.ibsys.app.pns_jax                     855           layout/weather_pager.xml|layout/closings.xml|l...
# com.knu.ibuttons                          12                                                          NaN
# com.icaw.guessthecar                      15                                                          NaN

# %%
# How many apps use this horizontal paging ?
h = HTML("<h2>How many apps ever used this horizontal paging in any release?</h2>"); h
# Out:
# <h2>How many apps ever used this horizontal paging in any release?</h2>

# %%
df_h_paging_adoption = find_usage_in_any_release(df_h_paging, 'use_android.support.v4.view.ViewPager_elements', True)
df_h_paging_adoption.head()
# Out:
#                                           available_versions  \
# package
# com.monotype.android.font.fonts4fun.metal                  3
# com.airkast.WKJSFM                                         2
# com.ibsys.app.pns_jax                                      2
# com.knu.ibuttons                                           2
# com.icaw.guessthecar                                       2
#
#                                           use_android.support.v4.view.ViewPager_elements_first_supported_version  \
# package
# com.monotype.android.font.fonts4fun.metal                                                NaN
# com.airkast.WKJSFM                                                                       NaN
# com.ibsys.app.pns_jax                                                                    855
# com.knu.ibuttons                                                                         NaN
# com.icaw.guessthecar                                                                     NaN
#
#                                           support_this_feature
# package
# com.monotype.android.font.fonts4fun.metal                False
# com.airkast.WKJSFM                                       False
# com.ibsys.app.pns_jax                                     True
# com.knu.ibuttons                                         False
# com.icaw.guessthecar                                     False

# %%
arr = np.array(df_h_paging_adoption['support_this_feature'], dtype= bool) + 0
tmp = df_h_paging_adoption
try:
    tmp.insert(0, 'binary_value', arr)
except ValueError:
    pass
tmp.groupby('support_this_feature').count().plot(kind='pie', y='binary_value',
                      autopct='%1.1f%%', title='Horizontal Paging Use',
                      figsize=(4,4), colors=['r', 'g'], fontsize=20)
print('Number of apps that use this feature: ' + 
      str(len(tmp.loc[tmp.support_this_feature == True])) +
      ' out of ' + str(len(tmp)) + ' apps.')
# Out:
# Number of apps that use this feature: 4524 out of 22162 apps.

# %%
# How many apps use this horizontal paging ?
h = HTML("<h2>How many apps that no longer use this horizontal paging in their recent release?</h2>"); h
# Out:
# <h2>How many apps that no longer use this horizontal paging in their recent release?</h2>

# %%
df_h_still_using = find_use_in_latest_release(df_h_paging, 'use_android.support.v4.view.ViewPager_elements')
df_h_still_using.head()
# Out:
#                                  available_versions  \
# package
# com.ibsys.app.pns_jax                             2
# com.mdv.IrelandCompanion                          2
# com.benigumo.kaomoji                              8
# com.priceline.android.negotiator                  4
# ru.tentracks.android                              2
#
#                                  use_android.support.v4.view.ViewPager_elements_use_in_latest_version  \
# package
# com.ibsys.app.pns_jax                                                           974
# com.mdv.IrelandCompanion                                                        123
# com.benigumo.kaomoji                                                      201406220
# com.priceline.android.negotiator                                                 96
# ru.tentracks.android                                                             40
#
#                                  support_this_feature
# package
# com.ibsys.app.pns_jax                            True
# com.mdv.IrelandCompanion                         True
# com.benigumo.kaomoji                             True
# com.priceline.android.negotiator                 True
# ru.tentracks.android                             True

# %%
arr = np.array(df_h_still_using['support_this_feature'], dtype= bool) + 0
tmp = df_h_still_using
try:
    tmp.insert(0, 'binary_value', arr)
except ValueError:
    pass
tmp.groupby('support_this_feature').count().plot(kind='pie', y='binary_value',
                      autopct='%1.1f%%', title='Horizontal Paging Use in Latest release',
                      figsize=(4,4), colors=['r', 'g'], fontsize=20)
print('Number of apps that no longer use this feature: ' + 
      str(len(tmp.loc[tmp.support_this_feature == False])) +
      ' out of ' + str(len(tmp)) + ' apps.')
# Out:
# Number of apps that no longer use this feature: 149 out of 4524 apps.

# %%
# Run get_diff to get changes using a script and do not run it on ipython notebook ever!
df_widget_changes = pd.read_csv('/Users/Khalid/git/appsmining/results/chi-15/tmp/appswidgets_changes.csv')
df_widget_changes.head()
# Out:
#                        package  number_of_versions  widgets_changes
# 0                     Air.Lite                   2                0
# 1  Animaonline.FanFiction.Free                   2                0
# 2       AutomateIt.mainPackage                   2                0
# 3          B4A.Agroid_software                   3                0
# 4   B4A.BigFivePersonalityTest                   2                0

# %%
mean(df_widget_changes.widgets_changes)
# Out:
# 0.019029301031265346

# %%
max(df_widget_changes.widgets_changes)
# Out:
# 19

# %%
min(df_widget_changes.widgets_changes)
# Out:
# -19
